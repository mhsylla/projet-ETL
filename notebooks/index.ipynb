# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/compets/wc_matches_historical.csv")

# %%
df
# Out:
#            match_id  wc_year        stage        date      home_team  \
# 0         WC1930_01     1930  Group Stage  1930-07-13         France
# 1         WC1930_02     1930  Group Stage  1930-07-13  United States
# 2         WC1930_03     1930  Group Stage  1930-07-15     Yugoslavia
# 3         WC1930_04     1930  Group Stage  1930-07-16        Romania
# 4         WC1930_05     1930  Group Stage  1930-07-17      Argentina
# ..              ...      ...          ...         ...            ...
# 112  WC2022_R16_NED     2022  Round of 16  2022-12-03    Netherlands
# 113  WC2022_R16_MAR     2022  Round of 16  2022-12-05        Morocco
# 114  WC2022_R16_CRO     2022  Round of 16  2022-12-05        Croatia
# 115  WC2022_R16_BRA     2022  Round of 16  2022-12-05         Brazil
# 116  WC2022_R16_POR     2022  Round of 16  2022-12-06       Portugal
#
#          away_team  home_goals  away_goals  aet penalties  home_pen_goals  \
# ...
